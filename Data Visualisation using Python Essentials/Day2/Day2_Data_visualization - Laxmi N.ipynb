# %% [markdown]
# **Day 2 - Data visualization using Python - Matplotlib**

# %% [markdown]
# Time-series: Line Plot
#
# Single Discrete Variable: Bar Plot, Pie Plot
#
# Single Continuous Variable:  Histogram, Density or KDE Plot, Box-Whisker Plot
#
# Two Continuous Variable: Scatter Plot

# %% [markdown]
# Line Plot

# %%
## https://hub.gke2.mybinder.org/user/ipython-ipython-in-depth-2l7k3yeo/notebooks/binder/Index.ipynb

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
from numpy.random import randn, randint, uniform, sample

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y1 = [1, 3, 5, 3, 1, 3, 5, 3, 1]
y2 = [2, 4, 6, 4, 2, 4, 6, 4, 2]
plt.plot(x, y1, label="line L")
plt.plot(x, y2, label="line H")
plt.plot()

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Line Graph")
plt.legend()
plt.show()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# Bar Chart

# %%
## Bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y, label = "x-y variation") 
plt.bar(x2, y2, color = 'g', label = "x2-y2") 
plt.title('Bar graph') 
plt.xlabel('X axis') 
plt.ylabel('Y axis')  
plt.legend()
plt.show()

# %%
x1 = [1, 3, 4, 5, 6, 7, 9]
y1 = [4, 7, 2, 4, 7, 8, 3]

x2 = [2, 4, 6, 8, 10]
y2 = [5, 6, 2, 6, 2]

# Colors: https://matplotlib.org/api/colors_api.html

plt.bar(x1, y1, label="Blue Bar", color='b')
plt.bar(x2, y2, label="Green Bar", color='g')
plt.plot()

plt.xlabel("bar number")
plt.ylabel("bar height")
plt.title("Bar Chart Example")
plt.legend()
plt.show()

# %%
df = iris.drop(['species'], axis = 1)
df.iloc[0]  #data from 0th index
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
## Create a dataframe with 10rows on random numbers and 4 columns, (columns labelled as a,b,c,d) and plot a bar chart.
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df

# %% [markdown]
# Histograms

# %% [markdown]
# Histograms are likely familiar, and a hist function already exists in matplotlib. A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#
# To illustrate this, let’s remove the density curve and add a rug plot, which draws a small vertical tick at each observation. You can make the rug plot itself with the rugplot() function, but it is also available in distplot():

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27,9]) 
plt.hist(a) 
plt.title("histogram") 
plt.show()

# %%
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris['sepal_length'].plot.hist() #hist showcases distributn in x-axis and magnitude in y-axis
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist() ### iris.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = False, bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = iris.drop(['species'], axis = 1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.hist(color = '#FF33F4', alpha = 0.9, figsize=(10,10)) ##color hex code (with #code)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# Pie chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0.1, 0.1, 0.1)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.2f%%', shadow=True)

plt.axis('equal')
plt.show()

# %%
series = pd.Series([0.2]*5)
series
# Out:
# 0    0.2
# 1    0.2
# 2    0.2
# 3    0.2
# 4    0.2
# dtype: float64

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='Pie Plot'>

# %% [markdown]
# Scatter plot

# %% [markdown]
# The most familiar way to visualize a bivariate distribution is a scatterplot, where each observation is shown with point at the x and y values.

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2021-07-01', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2021-07-01', periods = 1000))
df.head()
# Out:
#                value
# 2021-07-01 -1.544387
# 2021-07-02 -1.388317
# 2021-07-03 -0.341412
# 2021-07-04  1.753910
# 2021-07-05  0.756680

# %%
ts.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
 sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']
